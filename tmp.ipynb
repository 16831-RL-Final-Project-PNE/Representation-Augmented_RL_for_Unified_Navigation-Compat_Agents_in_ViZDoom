# %%
import torch

ckpt = torch.load("/workspace/Representation-Augmented_RL_for_Unified_Navigation-Compat_Agents_in_ViZDoom/checkpoints/dreamerv2_basic_run1_iter_30.pt")
# Out:
# /tmp/ipykernel_145465/450959277.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
ckpt['config']
# Out:
# DreamerV2Config(total_iterations=200, steps_per_iteration=4096, learning_rate={'world_model': 0.0005, 'actor_model': 1e-05, 'value_model': 1e-05}, gamma=0.99, gae_lambda=0.95, epochs=4, collect_intervals=1, eval_episodes=10, eval_interval=1, eval_log_path='./logs/dreamerv2_basic_run1_eval.npz', eval_deterministic=False, log_dir='./logs/tb_dreamerv2_basic', checkpoint_dir='./checkpoints', checkpoint_name='dreamerv2_basic_run1', save_every=5, embedding_size=256, batch_size=128, grad_clip_norm=10.0, use_dino_v3=True, dino_v3_model_name='facebook/dinov3-vits16-pretrain-lvd1689m', dino_v3_freeze_backbone=True, use_slow_target=True, slow_target_fraction=0.05, rssm_deter_size=200, rssm_category_size=20, rssm_class_size=20, rssm_node_size=100, rssm_seq_len=20, rssm_horizon=15, kl_use_kl_balance=True, kl_balance_scale=0.5, kl_use_free_nats=True, kl_free_nats=5.0, actor_grad='reinforce', actor_entropy_scale=0.1, actor_layers=3, actor_node_size=100, actor_train_noise=0.4, actor_eval_noise=0.0, 
# ...
